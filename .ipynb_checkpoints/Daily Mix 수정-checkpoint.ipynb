# %% [markdown]
# # Daily Mix

# %%
import pandas as pd
import numpy as np
import requests
import pymysql
import json
import os
import time
import shutil
import random
import cv2
from PIL import Image
import shutil
from datetime import datetime
import time

# %%
def connect():    
    config = {
    "user":'admin',
    "password":"InDJ20190301!@",
    "host":"nas.indj.me",
    "database":"indj",
    "port": 3333
    }

    conn=pymysql.connect(**config)
    cursor = conn.cursor()
    
    return cursor

# %%
user_idx = 29

# %%
start = time.time()

time_of_channel_name = datetime.today().strftime("%Y_%m_%d %H:%M:%S")

cursor = connect()

sql = """
    SELECT tag_idx
    FROM user_tag 
    WHERE user_idx = {} AND TYPE = 3
""".format(user_idx)

cursor.execute(sql)
user_tag = cursor.fetchall()

tag = []
for i in range(len(user_tag)):
    tag.append(int(user_tag[i][0]))

sql = """
    SELECT tag_idx
    FROM user_tag 
    WHERE user_idx = {} AND TYPE = 1
""".format(user_idx)

cursor.execute(sql)
result = cursor.fetchall()

for i in range(len(result)):
    
    music_list = []
    music_title = []
    artist_name = []
    
    sql = """
        SELECT name
        FROM artist
        WHERE idx = {}
    """.format(result[i][0])
    cursor.execute(sql)

    find_artist_name = cursor.fetchall()
    
    sql = """
            SELECT
            t.idx, t.name, COUNT(t.name) AS cnt
            FROM tag AS t
            JOIN artist_album_genre AS aag ON t.idx = aag.tag_idx
            JOIN artist_album_re AS aar ON aag.album_idx = aar.album_idx
            JOIN artist AS a ON aar.artist_idx = a.idx
            WHERE a.idx = {}
            GROUP BY t.name
            ORDER BY cnt desc
    """.format(result[i][0])
    
    cursor.execute(sql)

    find_genre = cursor.fetchall()
    genre = find_genre[0][0]
    
    sql = """
        SELECT aam.idx, aam.`file`, t.idx, t.name
        FROM user_tag AS ut
        JOIN tag AS t ON ut.tag_idx = t.idx
        JOIN ai_channel_tag AS act ON t.idx = act.tag_idx
        JOIN ai_channel_music AS acm ON act.ai_channel_idx = acm.ai_channel_idx
        JOIN artist_album_music AS aam ON acm.music_idx = aam.idx
        JOIN artist_album_re AS aar ON aam.album_idx = aar.album_idx
        JOIN artist AS a ON aar.artist_idx = a.idx
        WHERE ut.user_idx = {} AND a.idx = {} AND ut.`type` = 3 AND aam.`file` NOT LIKE '%inst.%' AND aam.`file` NOT LIKE '%_album%'
        GROUP BY aam.idx
    """.format(user_idx, result[i][0])
    cursor.execute(sql)

    result2 = cursor.fetchall()
    
    if result2 == ():
        sql = """
            SELECT aam.idx, aam.`file`
            FROM artist AS a
            JOIN artist_album_re AS aar ON a.idx = aar.artist_idx
            JOIN artist_album_music AS aam ON aar.album_idx = aam.album_idx
            WHERE a.idx = {} AND aam.`file` NOT LIKE '%inst.%' AND aam.`file` NOT LIKE '%_album%'
            GROUP BY aam.idx
        """.format(result[i][0])
        
        cursor.execute(sql)
        result2 = cursor.fetchall()
   
    if len(result2) > 4:
        extract_list = random.sample(result2, k=4)
    else:
        extract_list = random.sample(result2, k=len(result2))
    
    for k in range(len(extract_list)):
        music_list.append(extract_list[k][0])
        music_title.append(extract_list[k][1])

    sql = """
        SELECT
        sml.sml_artist_idx, a.name
        FROM artist_sml AS sml
        JOIN artist AS a ON a.idx = sml.sml_artist_idx
        WHERE sml.artist_idx = {}
    """.format(result[i][0])
    cursor.execute(sql)

    result3 = cursor.fetchall()
    
    if result3 == ():
#         print('유사 x', result[i][0])
        continue

    for j in range(len(result3)):
        
        sql = """
        SELECT name
        FROM artist
        WHERE idx = {}
        """.format(result3[j][0])
        cursor.execute(sql)

        find_artist_name2 = cursor.fetchall()
        
        artist_name.append(find_artist_name2[0][0])

        sql = """
        SELECT aam.idx, aam.`file`, t.idx, t.name
        FROM user_tag AS ut
        JOIN tag AS t ON ut.tag_idx = t.idx
        JOIN ai_channel_tag AS act ON t.idx = act.tag_idx
        JOIN ai_channel_music AS acm ON act.ai_channel_idx = acm.ai_channel_idx
        JOIN artist_album_music AS aam ON acm.music_idx = aam.idx
        JOIN artist_album_re AS aar ON aam.album_idx = aar.album_idx
        JOIN artist AS a ON aar.artist_idx = a.idx
        WHERE ut.user_idx = {} AND a.idx = {} AND ut.`type` = 3 AND aam.`file` NOT LIKE '%inst.%' AND aam.`file` NOT LIKE '%_album%'
        GROUP BY aam.idx
        """.format(user_idx, result3[j][0])
        cursor.execute(sql)

        result4 = cursor.fetchall()

        if len(result4) == 0:
            sql = """
            SELECT aam.idx, aam.`file`
            FROM artist AS a
            JOIN artist_album_re AS aar ON a.idx = aar.artist_idx
            JOIN artist_album_music AS aam ON aar.album_idx = aam.album_idx
            WHERE a.idx = {} AND aam.`file` NOT LIKE '%inst.%' AND aam.`file` NOT LIKE '%_album%'
            GROUP BY aam.idx
            """.format(result3[j][0])
            
            cursor.execute(sql)
            result4 = cursor.fetchall()

        if len(result4) > 3:
            extract_list2 = random.sample(result4, k=3)
        else:
            extract_list2 = random.sample(result4, k=len(result4))

        for k in range(len(extract_list2)):
            music_list.append(extract_list2[k][0])
            music_title.append(extract_list2[k][1])    
    
    channel_artist = random.sample(artist_name, k=1)
    count = 0
    if len(music_list) > 17:
        random.shuffle(music_list)
#         image_reshape(music_list, get_images)
        
#         file_list = os.listdir('./back') 
#         back_images = [file for file in file_list if file.endswith(".png")]  
#         for b in range(len(back_images)):
#             if genre == int(back_images[b].replace('.png','')):
#                 e = genre
#                 generate_image(e)
#                 break
#             else:
#                 e = None
#                 continue
                
#         if e != None:
            
        channel_name = find_artist_name[0][0] + ', ' + channel_artist[0] + '와(과) 유사한 아티스트 Daily Mix_'+time_of_channel_name
        print(user_idx, channel_name, tag)
        print('music_list_len:',len(music_title))
        print(music_title)
        count += 1
        
    if count == 10:
        break
        
print("총 소요 시간 :", time.time()-start)
# Out:
# 29 볼빨간사춘기, 이아립와(과) 유사한 아티스트 Daily Mix_2020_06_28 22:31:04 [139, 79, 45, 47, 64, 256, 261, 501]
# music_list_len: 45
# ['볼빨간사춘기-나의 사춘기에게', '볼빨간사춘기-심술', '볼빨간사춘기-워커홀릭', '볼빨간사춘기-빈칸을 채워주시오', '이아립-조언', '이아립-짙어만 갑니다', '이아립-시 헤는 밤', '10CM-봄이 좋냐', '10CM-안아줘요', '10CM-새벽 4시', '신현희와김루트-PARADISE', '슈가볼(Sugarbowl)-How Was Your Day', '슈가볼(Sugarbowl)-이렇게 한 걸음씩', '슈가볼(Sugarbowl)-농담 반 진담 반', '어쿠루브(Acourve)-그냥 다 미안', '어쿠루브(Acourve)-고백', '어쿠루브(Acourve)-하고 싶은 말 (feat.
윤종신)', '가인, 라디(Ra.D)-Take Out', '가인, 조형우-2시의 데이트', '현아-FLOWER SHOWER', '현아-어때', '현아-베베 (BABE)', 'Apink (에이핑크)-NoNoNo', 'Apink (에이핑크)-Oh Yes', '허각, Apink (에이핑크), VICTON(빅톤)-오아시스', '에이프릴(APRIL)-꿈사탕', '에이프릴(APRIL)-파랑새', '에이프릴(APRIL)-Muah!', 'EXO-CBX (첸백시)-花요일 (Blooming Day)', 'EXO-CBX (첸백시)-Cherish', 'EXO-CBX (첸백시)-아름다운 강산', '포미닛(4minute)-HUH', '포미닛(4minute)-Hot Issue', '포미닛(4minute)-이름이 뭐예요']
# 29 거미, 이적와(과) 유사한 아티스트 Daily Mix_2020_06_28 22:31:04 [139, 79, 45, 47, 64, 256, 261, 501]
# music_list_len: 49
# ['거미, 규현 (KYUHYUN)-우연히 그대', '거미-기억상실', '거미-날 그만 잊어요', '거미-친구라도 될 걸 그랬어', '바이브-가을 타나 봐', '바이브-사진을 보다가', '바이브-About Me', '어반자카파-Get (feat. Beenzino)', '어반자카파-기분 좋은 날', '어반자카파-Moai', '정인-장마', '정인, 윤종신-오르막길', '정인, 개리-자전거', '포맨-못해 (feat. 美)', '포맨-후회한다', '포맨-안아보자', '원티드(Wanted), J.Lee-술버릇', '원티드(Wanted), J.Lee-I Promise You', '윤종신, J.Lee-두 이별', '서인국-봄 타나봐 (BOMTANABA)', '서인국, 지아(Zia)-이별남녀', '양파-애송이의 사랑', 'BMK-편지 (김광진)', 'BMK-손금', 'BMK-혼자 한 이별', '제이(J.ae)-어제처럼', '제이(J.ae)-831 8', '주보라, 진성은-Reflection', '주보라-멈춘 시계', '주보라-U', '리사(Lisa)-Always', '리사(Lisa)-피눈물', '리사(Lisa), J-Min(제이민)-아름다운 강산 (2017 미스코리아 진~달래, 옷도 노래 취미도 노래 나는야 개나리)', '화요비, 태하-같이 있어줘', '화요비-나의 우주', '더 네임(The Name)-For You Live', '더 네임(The Name)-Used By You', '더 네임(The Name)-그녀를 찾아주세요', '노엘(NoeL)-You', '노엘(NoeL)-Blessing', '노엘(NoeL)-사소한 편지', "주희-She's Mine", '메이다니(MAYDONI)-다니맘대로해', 'THERAY(더레이)-발라드', 'THERAY(더레이)-LETTER', 'THERAY(더레이)-아니 아니 그게 아니라 (feat. 아이스펍)', '이적-하필', '이적-빨래', '이적-숫자']
# 29 기리보이, 렉스디와(과) 유사한 아티스트 Daily Mix_2020_06_28 22:31:04 [139, 79, 45, 47, 64, 256, 261, 501]
# music_list_len: 47
# ['기리보이-그 정도 쯤이야', 'Goretexx, 기리보이, 블랙넛(Black Nut), BILL STAX(빌스택스), C JAMM, 그냥노창, 스윙스(Swings)-[19금]카니발갱', '기리보이-왕복 30분 (feat. 신지수)', '기리보이-술자리', '레디(Reddy)-생각해 (Feat. 박재범)', '레디(Reddy)-Ocean View', '레디(Reddy)-즐겨 (Feat. Chancellor)', '크루셜스타(Crucial Star)-밀린 일', '크루셜스타(Crucial Star)-Coffee (Feat. Donutman)', '크루셜스타(Crucial Star)-One', "샘김(Sam Kim), 로꼬-Think About' Chu (Prod. By 박근태)", '로꼬-지나쳐 (Feat. DEAN)', '로꼬-감아 (feat. Crush)', 'C JAMM-[19금]pr0ve', 'C JAMM-Know', 'C JAMM-왈', '개코-Vacation (Feat. SOLE)', '개코-바빠서 (Feat. 헤이즈)', '개코-은색 소나타 (feat. Crush) (Silver Sonata)', '산이(San E)-모해(mohae) (Feat. 볼빨간사춘기)', '산이(San E)-Me You (feat. 백예린 Of 15&)', '산이(San E), 레이나 [애프터스쿨]-한여름밤의 꿀', '버벌진트(Verbal Jint), 산이(San E), 팬텀, 피타입, 이루펀트(Eluphant), 키디비(KittiB), HENNEY (헤니), 그리 (GREE), DJ Juice(디제이 쥬스)-[19금]BRAND NEW SHIT', "제시(Jessi), 그리 (GREE)-I'M GOOD", '버벌진트(Verbal Jint), 범키, 이루펀트(Eluphant), 한해, 칸토, 그리 (GREE), 옌자민-다 해도 돼', 'IMLAY, 식케이 (Sik-K)-데칼코마니 (Decalcomanie)', '식케이 (Sik-K)-RING RING (Feat. 개코)', '식케이 (Sik-K)-WHY YOU (Prod. GXXD)', '키썸(Kisum)-내게 인사해주세요 (Feat. 우디)', '키썸(Kisum)-잘자 (Sleep Tight) (Feat. 길구봉구)', '키썸(Kisum)-맥주 두 잔', '소유 (SOYOU), 매드 클라운(Mad Clown)-착해 빠졌어 (Stupid In Love)', '소유 (SOYOU), 매드 클라운(Mad Clown)-비가 오면', '보아 (BoA), 매드 클라운(Mad Clown)-오늘 밤', 'BOBBY-꽐라', 'MOBB (MINO & BOBBY)-빨리 전화해 (Feat. KUSH)', 'MOBB (MINO & BOBBY)-붐벼', '박재범(Jay Park), Illson (더블케이), 보이비-REBORN', '레디(Reddy), 지투(G2)-Thank You (Feat. 달총 of CHEEZE)', '레디(Reddy), 스웨이디(Sway D), 팔로알토 (Paloalto), 지투(G2), 윤비(YunB), 허클베리피(Huckleberry P), 조원우 (Jowonu)-Air', 'E SENS-DANCE', 'E SENS-RADAR (FEAT. 김심야)', 'E SENS-Unknown Verses', '렉스디-#불편해 (feat. 강민희 (미스에스))', '칸토-말만해 (What You Want) (feat. 김성규)', '언터쳐블-No Make Up', '언터쳐블-다줄께 (feat. 송지은)']
# 29 버스커 버스커(Busker Busker), 스탠딩 에그(Standing Egg)와(과) 유사한 아티스트 Daily Mix_2020_06_28 22:31:04 [139, 79, 45, 47, 64, 256, 261, 501]
# music_list_len: 30
# ['버스커 버스커(Busker Busker)-가을밤', '버스커 버스커(Busker Busker)-동경소녀', '버스커 버스커(Busker Busker)-네온사인', '버스커 버스커(Busker Busker)-봄바람', '데이브레이크(DAYBREAK)-Mellow', '데이브레이크(DAYBREAK)-좋다', '데이브레이크(DAYBREAK)-꽃길만 걷게 해줄게', '정회성(Hoe Seeing Jeong)-너의뒤에서', '카더가든-Sarah', '카더가든-Home Sweet Home', '카더가든-Beyond (Feat. O3ohn)', '잔나비-JUNGLE', '잔나비-꿈나라 별나라', '잔나비-She (Hidden Track No.V 1월 선정곡)', '장범준-회상', '스탠딩 에그(Standing Egg)-그래도 좋아', '스탠딩 에그(Standing Egg)-잠 못 드는 그대에게', '스탠딩 에그(Standing Egg)-휴식', '마크툽(Maktub)-Love Love Love (feat. 구윤회, 이라온)', '마크툽(Maktub), 반광옥-Always And Forever', '마크툽(Maktub), 이라온-낯설어', '소란(SORAN)-너를 공부해', '소란(SORAN)-Perfect Day', '소란(SORAN), Sam Ock(샘 옥), 꽃잠 프로젝트(GGot Jam Project)-자꾸 생각나', '프롬(Fromm)-Our Night', '프롬(Fromm)-달밤댄싱', '프롬(Fromm)-With You', '페퍼톤스(Peppertones)-Bikini', '페퍼톤스(Peppertones)-FAST', '페퍼톤스(Peppertones)-FOOL']
# 29 TWICE (트와이스), 2NE1와(과) 유사한 아티스트 Daily Mix_2020_06_28 22:31:04 [139, 79, 45, 47, 64, 256, 261, 501]
# music_list_len: 56
# ['TWICE (트와이스)-Heart Shaker', 'TWICE (트와이스)-하루에 세번', 'TWICE (트와이스)-CHEER UP', 'TWICE (트와이스)-OOH-AHH하게', '아이오아이(I.O.I)-Pick Me', '아이오아이(I.O.I)-Doo Wap', '아이오아이(I.O.I)-Whatta Man (Good man)', 'f(x)-All Mine', 'f(x)-Red Light', 'f(x)-Goodbye Summer (f(Amber+Luna+Krystal) (feat. D.O. Of EXO-K))', '비투비-아름답고도 아프구나', '비투비-Last Day', '비투비-꽃보다 그녀', '오마이걸(OH MY GIRL)-소나기', '오마이걸(OH MY GIRL)-BUNGEE (Fall in Love)', '오마이걸(OH MY GIRL)-불꽃놀이 (Remember Me)', '2NE1-Come Back Home', '2NE1-아파 (Slow)', '2NE1-너 아님 안돼', '우주소녀-Take My Breath', '우주소녀-부탁해', '우주소녀-Boogie Up', '여자친구(GFRIEND)-해야 (Sunrise)', '여자친구(GFRIEND)-시간을 달려서 (Rough)', '여자친구(GFRIEND)-교차로 (Crossroads)', '인피니트(Infinite)-추격자', '인피니트(Infinite)-Back', '인피니트(Infinite)-Last Romeo', '현아-Lip & Hip', '현아-어때', '현아-Bubble Pop!', 'Jessica(제시카)-Fly (feat. Fabolous)', 'Jessica(제시카)-World Of Dreams', 'Jessica(제시카), 크리스탈 (KRYSTAL)-Butterfly', '허각, Apink (에이핑크), VICTON(빅톤)-오아시스', 'Apink (에이핑크)-동화 같은 사랑', 'Apink (에이핑크)-Good Morning Baby', '다이아(DIA)-왠지 (Somehow)', '다이아(DIA)-그 길에서', '다이아(DIA)-우우 (Woowoo)', '티파니 (TIFFANY)-Only One', '티파니 (TIFFANY)-Once in a Lifetime', '티파니 (TIFFANY)-나 혼자서 (feat. 소녀시대-티파니)', '티아라(T-ara)-Sexy Love', '티아라(T-ara)-Bo Peep Bo Peep', '티아라(T-ara)-Day By Day', '포미닛(4minute)-이름이 뭐예요', '포미닛(4minute)-Hot Issue', '포미닛(4minute)-미쳐', '오렌지캬라멜(Orange Caramel)-립스틱 (Lipstick)', '애프터 스쿨(After School)-Shampoo', '애프터 스쿨(After School)-첫사랑', '애프터 스쿨(After School)-Virgin', '소나무(SONAMOO)-SUGAR BABY', '소나무(SONAMOO)-Deja Vu', '소나무(SONAMOO)-I (knew it)']
# 29 에픽하이 (EPIK HIGH), MC 스나이퍼(MC Sniper)와(과) 유사한 아티스트 Daily Mix_2020_06_28 22:31:04 [139, 79, 45, 47, 64, 256, 261, 501]
# music_list_len: 48
# ['에픽하이 (EPIK HIGH)-선곡표 (feat. DJ Zio)', '에픽하이 (EPIK HIGH)-춥다 (feat. 이하이)', '에픽하이 (EPIK HIGH)-[19금]Born Hater (feat. 빈지노, 버벌진트, B.I, Mino, Bobby)', '에픽하이 (EPIK HIGH)-우산 (feat. 윤하)', '긱스(Geeks)-문제아 (Feat. 스텔라장)', '긱스(Geeks)-Woo', '긱스(Geeks)-가끔 (feat. Crush, 기리보이)', '리쌍(Leessang)-헤어지지 못하는 여자, 떠나가지 못하는 남자 (feat. 정인)', '리쌍(Leessang)-주마등 (feat. 우혜미)', '리쌍(Leessang)
오델)-True Colours', 'Tom Odell(톰 오델)-Another Love', 'Tom Odell(톰 오델)-Here I Am (Kid Arkade Remix)', 'Kristen Bell(크리스틴 벨), Idina Menzel(이디나 멘젤)-For The First Time In Forever', 'Idina Menzel(이디나 멘젤)-Let It Go', 'Keren Ann(케렌 앤)-Seventeen', 'Keren Ann(케렌 앤)-Ailleurs', 'Keren Ann(케렌 앤)-Not Going Anywhere', 'Regina Spektor(레지나 스펙터)-Fidelity', 'Regina Spektor(레지나 스펙터)-Field Below', 'Regina Spektor(레지나 스펙터)-Samson', 'M.Y.M.P-Love Stood Still', 'Seal(실)-Kiss From A Rose', 'Demi Lovato(데미 로바토)-Confident', 'Demi Lovato(데미 로바토)-Kingdom Come (feat. Iggy Azalea)', 'Demi Lovato(데미 로바토)-Give Your Heart a Break', 'Skylar Grey(스카일라 그레이)-Stand By Me', 'Train(트레인), Skylar Grey(스카일라 그레이)-Mai Tais', 'Jewel(쥬얼)-Intuition', 'Karmin(카르민)-Brokenhearted', 'Karmin(카르민)-Hate To Love You', 'Emi Meyer(에미 마이어)-Room Blue', 'Emi Meyer(에미 마이어)-One Good Song', 'Shane Filan(셰인 필란)-You And Me', 'Shane Filan(셰인 필란)-Make You Feel My Love', 'Paolo Nutini(파올로 누티니)-Iron Sky', 'Paolo Nutini(파올로 누티니)-New Shoes', 'Ryan Cabrera(라이언 카브레라)-Take It All Away', 'Ryan Cabrera(라이언 카브레라)-On The Way Down', 'Ryan Cabrera(라이언 카브레라)-True', 'Lorde(로드)-Liability', 'Lorde(로드)-Supercut (feat. Run The Jewels) (El-P Remix)', 'Lorde(로드)-Homemade Dynamite (feat. SZA, Post Malone, Khalid) (REMIX)', 'Rufus Wainwright(루퍼스 웨인라이트)-Sometimes You Need', 'Rufus Wainwright(루퍼스 웨인라이트)-Jericho', "Rufus Wainwright(루퍼스 웨인라이트)-I Don't Know What It Is"]
# 29 넬(NELL), 이지(Izi)와(과) 유사한 아티스트 Daily Mix_2020_06_28 22:31:04 [139, 79, 45, 47, 64, 256, 261, 501]
# music_list_len: 26
# ['넬(NELL)-In Days Gone By', '넬(NELL)-고양이', '넬(NELL)-습관적 아이러니', '넬(NELL), 그루비룸 (GroovyRoom)-오늘은', '김윤아-Going Home', '김윤아-다 지나간다', '김윤아-길', '우연주-우리가 사랑했을까', '러브홀릭(Loveholic)-놀러와', '김사랑-너란 놈 (Acoustic)', '김사랑-Goodbye', '김사랑-ICU', "펄스데이(Pearl's Day)-차마", "펄스데이(Pearl's Day)-불어라 꽃바람", "펄스데이(Pearl's Day)-3분 고백", '러브홀릭스(Loveholics)-Butterfly', '러브홀릭스(Loveholics)-Butterfly (Play 크리스티나, 이승열, 호란, 알렉스, 박기영, 웨일, 정순용, 미키, 혜원, 장은아)', "러브홀릭스(Loveholics)-Butterfly (영화 '국가대표' OST 삽입곡)", '이지(Izi)-응급실', '이장혁-봄', '이장혁-불면', '어른아이(Adultchild)-Annabel Lee', '어른아이(Adultchild)-민들레 (Dandelion)', '어른아이(Adultchild)-Fool', '익스(Ex)-잘 부탁드립니다', '더더(THETHE)-내게 다시']
# 총 소요 시간 : 21.671038389205933
